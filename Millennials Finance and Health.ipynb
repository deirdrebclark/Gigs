# %%
#Get dependencies
import pandas as pd

# %% [markdown]
# #2010 Health Data

# %%
#Get 2010 health data from csv file
hc_data = pd.read_csv ('Resources/Pew_Millennials_Data.csv')

hc_df = pd.DataFrame(hc_data)
# Out:
#    resp  comp fproj  timezone  sfips     smsa  qcendiv sstate  phtype susr  \
# 0     2     1  4968         1  36061  35620.0        2     NY     1.0    U
# 1     4     1  4968         2  31055  36540.0        4     NE     1.0    U
# 2     5     1  4968         1  18023      0.0        3     IN     1.0    R
# 3     6     1  4968         1  18057  26900.0        3     IN     0.0    S
# 4     7     1  4968         1  51065  16820.0        5     VA     1.0    S
# 5     8     1  4968         1  24003  12580.0        5     MD     1.0    S
# 6    10     1  4968         1  42101  37980.0        2     PA     0.0    U
# 7    13     1  4968         1  37007  16740.0        5     NC     1.0    S
# 8    14     1  4968         2  12091  18880.0        5     FL     1.0    S
# 9    15     1  4968         2  29097  27900.0        4     MO     1.0    U
#
#    ...   fdate  fdow  phoneuse  adults psadjust  puadjust  wt1  weight  q46x  \
# 0  ...  100114     5         2       3        2       1.0  2.0   0.543     0
# 1  ...  100114     5         2       2        2       1.0  2.0   1.488     1
# 2  ...  100114     5         2       2        2       1.0  2.0   0.972     0
# 3  ...  100114     5         2       2        2       1.0  2.0   1.844     0
# 4  ...  100114     5         2       2        2       1.0  2.0   1.282     0
# 5  ...  100114     5         2       2        2       1.0  2.0   0.833     0
# 6  ...  100114     5         1       1        1       2.0  2.0   1.255     0
# 7  ...  100114     5         2       1        1       1.0  1.0   0.887     1
# 8  ...  100114     5         2       2        2       1.0  2.0   1.625     0
# 9  ...  100114     5         2       1        1       1.0  1.0   0.706     0
#
#    agegroups
# 0         29
# 1         45
# 2         45
# 3         97
# 4         64
# 5          0
# 6         64
# 7         64
# 8         64
# 9         64
#
# [10 rows x 189 columns]

# %%
#Pull only health answers with the response ID and age
hc_df = hc_df[['resp','q7.1','q7.2','q7.3','q7.4','q7.5','age','health']]

# %%
#Questions 7.1 - 7.5 respondent ranked which generation is healthier (= 35)
healthier_df = hc_df.loc[(hc_df['q7.1']==35) | (hc_df['q7.2']==35) | (hc_df['q7.3']==35) | \
                  (hc_df['q7.4']==35) | (hc_df['q7.5']==35)]
# Out:
#         resp  q7.1  q7.2  q7.3  q7.4  q7.5  age  health
# 129      158    27    35     0     0     0   68       1
# 305      396     1    35     0     0     0   57       1
# 331      428    35     0     0     0     0   21       1
# 980   100598    16    17    35     0     0   40       2
# 1083  100834    29    35     0     0     0   22       1
# 1503  200047    12    35     0     0     0   28       1

# %%
#Count how many millennials (ages 13 - 29) were insured in 2010
insured_df = hc_df.loc[(hc_df['health']==1) & (hc_df['age']>=13) & (hc_df['age']<=29)].sum()
uninsured_df = hc_df.loc[(hc_df['health']==2) & (hc_df['age']>=13) & (hc_df['age']<=29)].sum()

# %% [markdown]
# #2017 Health Data

# %%
#Get 2017 health data from csv file
health_data = pd.read_csv ('Resources/personsx.csv')

health_df = pd.DataFrame(health_data)

# %%
health_df.head(10)
# Out:
#    FPX  AGE_CHG  INTV_QRT  SEX  NOWAF  FSPOUS2  COHAB1  COHAB2  FCOHAB3  \
# 0    1      NaN         1    2    NaN      NaN     NaN     NaN      NaN
# 1    1      NaN         1    2    2.0      2.0     NaN     NaN      NaN
# 2    2      NaN         1    1    2.0      1.0     NaN     NaN      NaN
# 3    3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 4    1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
# 5    2      NaN         1    2    2.0      1.0     NaN     NaN      NaN
# 6    3      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 7    4      NaN         1    1    NaN      NaN     NaN     NaN      NaN
# 8    1      NaN         1    1    2.0      2.0     NaN     NaN      NaN
# 9    2      NaN         1    2    2.0      1.0     NaN     NaN      NaN
#
#    ASTATFLG  ...  EDUC1  ERNYR_P  ARMFTM7P  ARMFTM1P  ARMFTM2P  ARMFTM3P  \
# 0       1.0  ...      9      NaN       NaN       NaN       NaN       NaN
# 1       2.0  ...     14      NaN       NaN       NaN       NaN       NaN
# 2       0.0  ...     15      7.0       NaN       NaN       NaN       NaN
# 3       NaN  ...     10      NaN       NaN       NaN       NaN       NaN
# 4       1.0  ...     21     11.0       NaN       NaN       NaN       NaN
# 5       2.0  ...     18     11.0       NaN       NaN       NaN       NaN
# 6       NaN  ...      3      NaN       NaN       NaN       NaN       NaN
# 7       NaN  ...      0      NaN       NaN       NaN       NaN       NaN
# 8       1.0  ...     16      8.0       NaN       NaN       NaN       NaN
# 9       2.0  ...     15      8.0       NaN       NaN       NaN       NaN
#
#    ARMFTM4P  ARMFTM5P  ARMFTM6P  ENGLANG
# 0       NaN       NaN       NaN      1.0
# 1       NaN       NaN       NaN      1.0
# 2       NaN       NaN       NaN      1.0
# 3       NaN       NaN       NaN      1.0
# 4       NaN       NaN       NaN      1.0
# 5       NaN       NaN       NaN      1.0
# 6       NaN       NaN       NaN      1.0
# 7       NaN       NaN       NaN      1.0
# 8       NaN       NaN       NaN      1.0
# 9       NaN       NaN       NaN      1.0
#
# [10 rows x 602 columns]

# %%
#Pull only relevant health answers with the age
health_stat_df1 = health_df.loc[:,'AGE_P','SEX','PLAWKNOW','LAHCA1','LAHCA2','LAHCA17','LAHCA18', \
                                'LAUNIT29','LAUNIT30','LAUNIT33', 'LACHRONR','PDMED12M','PNMED12M']

health_stat_df2 = health_df.loc[:,'AGE_P','SEX','PHOSPYR2','HOSPNO','HPNITE','PHCHM2W','PHCHMN2W', \
               'PHCPH2WR','PHCPHN2W','PHCDV2W','PHCDVN2W','P10DVYR']

ins_cvg_df1 = health_df.loc[:,'AGE_P','SEX','NOTCOV','COVER','PLNWRKS1','HICOSTR1','PRPOLH2','HILAST2','HISTOP1','HISTOP2', \
                       'HISTOP3','HISTOP4','HISTOP5','HISTOP6','HISTOP10','HISTOP11','HISTOP12', \
                       'HISTOP13','HISTOP14']

ins_cvg_df2 = health_df.loc[:,'AGE_P','SEX','HINOTYR','HINOTMYR','FHICHNG','FHIKDBA','FHIKDBB', \
                       'FHIKDBC','FHIKDBD','FHIKDBF','FHIKDBH','FHIKDBI','FHIKDBK','FINCINT','HIKINDNK','HCSPFYR', \
                       'MEDBNOP','MEDBILL','MEDBPAY']


stat_df = health_df.loc[:,'AGE_P','SEX','PHSTAT','PLBORN','YRSINUS','CITIZENP','EDUC1']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-5c0f4433a233> in <module>()
#       1 #Pull only relevant health answers with the age
# ----> 2 health_stat_df1 = health_df.loc(axis=0)[:,'AGE_P','SEX','PLAWKNOW','LAHCA1','LAHCA2','LAHCA17','LAHCA18',                                 'LAUNIT29','LAUNIT30','LAUNIT33', 'LACHRONR','PDMED12M','PNMED12M']
#       3
#       4 health_stat_df2 = health_df.loc(axis=0)[:,'AGE_P','SEX','PHOSPYR2','HOSPNO','HPNITE','PHCHM2W','PHCHMN2W',                'PHCPH2WR','PHCPHN2W','PHCDV2W','PHCDVN2W','P10DVYR']
#       5
#
# C:\Users\deird\.conda\envs\PythonData\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# C:\Users\deird\.conda\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     803     def _getitem_tuple(self, tup):
#     804         try:
# --> 805             return self._getitem_lowerdim(tup)
#     806         except IndexingError:
#     807             pass
#
# C:\Users\deird\.conda\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     904         if self.axis is not None:
#     905             axis = self.obj._get_axis_number(self.axis)
# --> 906             return self._getitem_axis(tup, axis=axis)
#     907
#     908         # we may have a nested tuples indexer here
#
# C:\Users\deird\.conda\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1837                     raise ValueError("Cannot index with multidimensional key")
#    1838
# -> 1839                 return self._getitem_iterable(key, axis=axis)
#    1840
#    1841             # nested tuple slicing
#
# C:\Users\deird\.conda\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1131         else:
#    1132             # A collection of keys
# -> 1133             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1134             return self.obj._reindex_with_indexers(
#    1135                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# C:\Users\deird\.conda\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1084             if len(ax) or not len(key):
#    1085                 key = self._convert_for_reindex(key, axis)
# -> 1086             indexer = ax.get_indexer_for(key)
#    1087             keyarr = ax.reindex(keyarr)[0]
#    1088         else:
#
# C:\Users\deird\.conda\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_indexer_for(self, target, **kwargs)
#    4815         """
#    4816         if self.is_unique:
# -> 4817             return self.get_indexer(target, **kwargs)
#    4818         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#    4819         return indexer
#
# C:\Users\deird\.conda\envs\PythonData\lib\site-packages\pandas\core\indexes\range.py in get_indexer(self, target, method, limit, tolerance)
#     396         if not (is_integer_dtype(target_array) and target_array.ndim == 1):
#     397             # checks/conversions/roundings are delegated to general method
# --> 398             return super().get_indexer(target, method=method, tolerance=tolerance)
#     399
#     400         locs = target_array - start
#
# C:\Users\deird\.conda\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2978             target = target.astype(object)
#    2979             return this.get_indexer(
# -> 2980                 target, method=method, limit=limit, tolerance=tolerance
#    2981             )
#    2982
#
# C:\Users\deird\.conda\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3002                 )
#    3003
# -> 3004             indexer = self._engine.get_indexer(target._ndarray_values)
#    3005
#    3006         return ensure_platform_int(indexer)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'slice'
