# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
df = pd.read_csv("Output/2017_Health_Data.csv")
# Drop the null columns where all values are null

# Drop the null rows
df.head()
# Out:
#    Unnamed: 0  NOTCOV  HINOTYR  AGE_P  SEX  PLAWKNOW  PDMED12M  PNMED12M  \
# 0           0       2      2.0     79    2       2.0         2         2
# 1           1       2      2.0     55    2       2.0         1         1
# 2           2       2      2.0     49    1       2.0         1         2
# 3           3       2      2.0     16    1       NaN         2         2
# 4           4       2      2.0     37    1       2.0         2         2
#
#    LAUNIT17  LAHCA2  ...  EXCHANGE  WHONAM1  PRPOLH1  PLNWRKS1  DOINGLWP  \
# 0       NaN     NaN  ...       NaN      NaN      NaN       NaN       5.0
# 1       NaN     NaN  ...       2.0      2.0      NaN       1.0       5.0
# 2       NaN     NaN  ...       2.0      1.0      NaN       1.0       1.0
# 3       NaN     NaN  ...       2.0      2.0      NaN       1.0       NaN
# 4       NaN     NaN  ...       2.0      2.0      NaN       1.0       1.0
#
#    WRKMYR  ERNYR_P  POWBEN  PCHLDSP  PINCOT
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'NOTCOV', 'HINOTYR', 'AGE_P', 'SEX', 'PLAWKNOW',
#        'PDMED12M', 'PNMED12M', 'LAUNIT17', 'LAHCA2', 'LAHCA4', 'LAHCA6',
#        'LAHCA8', 'LAHCA10', 'LAHCA12', 'LAHCA14A', 'LAHCA16', 'LAHCA18',
#        'LAHCA20_', 'LAHCA22_', 'LAHCA24_', 'LAHCA25_', 'LAHCA26_', 'LAHCA27_',
#        'LAHCA28_', 'LAHCA29_', 'PDMED12M.1', 'PNMED12M.1', 'PHSTAT',
#        'MEDICAID', 'MAFLG', 'MACHMD', 'MXCHNG', 'MEDPREM', 'MDPRINC',
#        'PRIVATE', 'PRFLG', 'EXCHANGE', 'WHONAM1', 'PRPOLH1', 'PLNWRKS1',
#        'DOINGLWP', 'WRKMYR', 'ERNYR_P', 'POWBEN', 'PCHLDSP', 'PINCOT'],
#       dtype='object')

# %%
new2_df=df.drop(columns=["Unnamed: 0", "LAUNIT17","LAHCA2","LAHCA4","LAHCA6","LAHCA8","LAHCA10","LAHCA12","LAHCA14A","LAHCA16","LAHCA18","LAHCA20_","LAHCA22_","LAHCA24_","LAHCA25_","LAHCA26_","LAHCA27_","LAHCA28_","LAHCA29_","MAFLG","MACHMD","MXCHNG","MEDPREM","MDPRINC","PRFLG","PRPOLH1","EXCHANGE"])
new2_df
# Out:
#        NOTCOV  HINOTYR  AGE_P  SEX  PLAWKNOW  PDMED12M  PNMED12M  PDMED12M.1  \
# 0           2      2.0     79    2       2.0         2         2           2
# 1           2      2.0     55    2       2.0         1         1           1
# 2           2      2.0     49    1       2.0         1         2           1
# 3           2      2.0     16    1       NaN         2         2           2
# 4           2      2.0     37    1       2.0         2         2           2
# ...       ...      ...    ...  ...       ...       ...       ...         ...
# 72826       1      NaN     49    2       1.0         1         1           1
# 72827       2      2.0     40    2       1.0         1         2           1
# 72828       2      2.0     61    2       2.0         2         2           2
# 72829       2      2.0     66    1       2.0         2         2           2
# 72830       2      2.0     70    2       2.0         2         2           2
#
# ...

# %%
new2_df["PHSTAT"].value_counts(dropna=False)
# Out:
# 1    25109
# 2    22683
# 3    17432
# 4     5822
# 5     1711
# 7       50
# 9       24
# Name: PHSTAT, dtype: int64

# %%
indexNames = new2_df[new2_df['PHSTAT'] == 7].index

# %%
new2_df.drop(indexNames , inplace=True)

# %%
new2_df["PHSTAT"].value_counts(dropna=False)
# Out:
# 1    25109
# 2    22683
# 3    17432
# 4     5822
# 5     1711
# 9       24
# Name: PHSTAT, dtype: int64

# %%
indexNames2 = new2_df[new2_df['PHSTAT']==9].index

# %%
new2_df.drop(indexNames2, inplace=True)

# %%
new2_df["PHSTAT"].value_counts(dropna=False)
# Out:
# 1    25109
# 2    22683
# 3    17432
# 4     5822
# 5     1711
# Name: PHSTAT, dtype: int64

# %%
filterinfDataframe = new2_df[(new2_df['AGE_P'] > 25) & (new2_df['AGE_P'] < 39)]
filterinfDataframe
# Out:
#        NOTCOV  HINOTYR  AGE_P  SEX  PLAWKNOW  PDMED12M  PNMED12M  PDMED12M.1  \
# 4           2      2.0     37    1       2.0         2         2           2
# 5           2      2.0     36    2       2.0         2         2           2
# 8           2      2.0     29    1       2.0         2         2           2
# 9           2      2.0     34    2       2.0         2         2           2
# 13          2      2.0     33    2       2.0         1         1           1
# ...       ...      ...    ...  ...       ...       ...       ...         ...
# 72805       2      2.0     29    2       2.0         2         2           2
# 72810       2      2.0     34    1       2.0         2         2           2
# 72814       1      1.0     37    1       2.0         2         2           2
# 72818       2      2.0     31    1       2.0         2         2           2
# 72819       2      2.0     28    2       2.0         2         2           2
#
# ...

# %%
filterinfDataframe.to_csv("Output/filtered_health.csv",index=False)

# %%
milli_filtered = pd.read_csv('Output/filtered_health.csv')
print(milli_filtered.shape)
milli_filtered.head()
# Out:
# (11749, 20)
#    NOTCOV  HINOTYR  AGE_P  SEX  PLAWKNOW  PDMED12M  PNMED12M  PDMED12M.1  \
# 0       2      2.0     37    1       2.0         2         2           2
# 1       2      2.0     36    2       2.0         2         2           2
# 2       2      2.0     29    1       2.0         2         2           2
# 3       2      2.0     34    2       2.0         2         2           2
# 4       2      2.0     33    2       2.0         1         1           1
#
#    PNMED12M.1  PHSTAT  MEDICAID  PRIVATE  WHONAM1  PLNWRKS1  DOINGLWP  WRKMYR  \
# 0           2       3         3        1      2.0       1.0       1.0    12.0
# 1           2       2         3        1      1.0       1.0       1.0    12.0
# 2           2       2         3        1      1.0       1.0       1.0    12.0
# 3           2       1         3        1      2.0       1.0       1.0    12.0
# 4           1       2         3        1      2.0       1.0       5.0     NaN
#
#    ERNYR_P  POWBEN  PCHLDSP  PINCOT
# ...

# %%
milli_filtered.dtypes.value_counts()
# Out:
# int64      13
# float64     7
# dtype: int64

# %%
milli_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11749 entries, 0 to 11748
# Data columns (total 20 columns):
# NOTCOV        11749 non-null int64
# HINOTYR       9907 non-null float64
# AGE_P         11749 non-null int64
# SEX           11749 non-null int64
# PLAWKNOW      11749 non-null float64
# PDMED12M      11749 non-null int64
# PNMED12M      11749 non-null int64
# PDMED12M.1    11749 non-null int64
# PNMED12M.1    11749 non-null int64
# PHSTAT        11749 non-null int64
# MEDICAID      11749 non-null int64
# PRIVATE       11749 non-null int64
# WHONAM1       7623 non-null float64
# PLNWRKS1      7623 non-null float64
# DOINGLWP      11749 non-null float64
# WRKMYR        9992 non-null float64
# ERNYR_P       9992 non-null float64
# POWBEN        11749 non-null int64
# PCHLDSP       11749 non-null int64
# PINCOT        11749 non-null int64
# dtypes: float64(7), int64(13)
# memory usage: 1.8 MB

# %%
null_counts = milli_filtered.isnull().sum()
print("Number of null values in each column:\n{}".format(null_counts))
# Out:
# Number of null values in each column:
# NOTCOV           0
# HINOTYR       1842
# AGE_P            0
# SEX              0
# PLAWKNOW         0
# PDMED12M         0
# PNMED12M         0
# PDMED12M.1       0
# PNMED12M.1       0
# PHSTAT           0
# MEDICAID         0
# PRIVATE          0
# WHONAM1       4126
# PLNWRKS1      4126
# DOINGLWP         0
# WRKMYR        1757
# ERNYR_P       1757
# POWBEN           0
# PCHLDSP          0
# PINCOT           0
# dtype: int64

# %%
milli_filtered=milli_filtered.dropna()

# %%
X=milli_filtered.loc[:,["AGE_P","WRKMYR","ERNYR_P","NOTCOV","HINOTYR"]]
y=milli_filtered["PHSTAT"].values.reshape(-1, 1)

# %%
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (6988, 5) (6988, 1)

# %%
from sklearn.model_selection import train_test_split

### BEGIN SOLUTION

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (5241, 5)
# (5241, 1)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# C:\Users\test\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\test\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\test\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
# ...

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.41137187559626026
# Testing Data Score: 0.41957641671436746

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10]}")
# Out:
# First 10 Predictions:   [2 2 2 2 2 1 1 2 2 2]
# First 10 Actual labels: [[2]
#  [2]
#  [1]
#  [2]
#  [1]
#  [1]
#  [1]
#  [2]
#  [2]
#  [2]]
