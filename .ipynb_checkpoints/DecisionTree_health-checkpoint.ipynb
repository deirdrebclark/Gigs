# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import tree

# %%
df = pd.read_csv("Output/2017_Health_Data.csv")
# Drop the null columns where all values are null

# Drop the null rows
df.head()
# Out:
#    Unnamed: 0  AGE_P  SEX  PLAWKNOW  PDMED12M  PNMED12M  LAUNIT17  LAHCA2  \
# 0           0     79    2       2.0         2         2       NaN     NaN
# 1           1     55    2       2.0         1         1       NaN     NaN
# 2           2     49    1       2.0         1         2       NaN     NaN
# 3           3     16    1       NaN         2         2       NaN     NaN
# 4           4     37    1       2.0         2         2       NaN     NaN
#
#    LAHCA4  LAHCA6  ...  EXCHANGE  WHONAM1  PRPOLH1  PLNWRKS1  DOINGLWP  \
# 0     NaN     NaN  ...       NaN      NaN      NaN       NaN       5.0
# 1     NaN     NaN  ...       2.0      2.0      NaN       1.0       5.0
# 2     NaN     NaN  ...       2.0      1.0      NaN       1.0       1.0
# 3     NaN     NaN  ...       2.0      2.0      NaN       1.0       NaN
# 4     NaN     NaN  ...       2.0      2.0      NaN       1.0       1.0
#
#    WRKMYR  ERNYR_P  POWBEN  PCHLDSP  PINCOT
# 0     NaN      NaN       2        2       2
# 1     NaN      NaN       2        2       2
# 2    12.0      7.0       2        2       2
# 3     NaN      NaN       2        2       2
# 4    12.0     11.0       2        2       2
#
# [5 rows x 45 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'AGE_P', 'SEX', 'PLAWKNOW', 'PDMED12M', 'PNMED12M',
#        'LAUNIT17', 'LAHCA2', 'LAHCA4', 'LAHCA6', 'LAHCA8', 'LAHCA10',
#        'LAHCA12', 'LAHCA14A', 'LAHCA16', 'LAHCA18', 'LAHCA20_', 'LAHCA22_',
#        'LAHCA24_', 'LAHCA25_', 'LAHCA26_', 'LAHCA27_', 'LAHCA28_', 'LAHCA29_',
#        'PDMED12M.1', 'PNMED12M.1', 'PHSTAT', 'MEDICAID', 'MAFLG', 'MACHMD',
#        'MXCHNG', 'MEDPREM', 'MDPRINC', 'PRIVATE', 'PRFLG', 'EXCHANGE',
#        'WHONAM1', 'PRPOLH1', 'PLNWRKS1', 'DOINGLWP', 'WRKMYR', 'ERNYR_P',
#        'POWBEN', 'PCHLDSP', 'PINCOT'],
#       dtype='object')

# %%
new2_df=df.drop(columns=["Unnamed: 0", "LAUNIT17","LAHCA2","LAHCA4","LAHCA6","LAHCA8","LAHCA10","LAHCA12","LAHCA14A","LAHCA16","LAHCA18","LAHCA20_","LAHCA22_","LAHCA24_","LAHCA25_","LAHCA26_","LAHCA27_","LAHCA28_","LAHCA29_","MAFLG","MACHMD","MXCHNG","MEDPREM","MDPRINC","PRFLG","PRPOLH1","EXCHANGE"])
new2_df
# Out:
#        AGE_P  SEX  PLAWKNOW  PDMED12M  PNMED12M  PDMED12M.1  PNMED12M.1  \
# 0         79    2       2.0         2         2           2           2
# 1         55    2       2.0         1         1           1           1
# 2         49    1       2.0         1         2           1           2
# 3         16    1       NaN         2         2           2           2
# 4         37    1       2.0         2         2           2           2
# ...      ...  ...       ...       ...       ...         ...         ...
# 72826     49    2       1.0         1         1           1           1
# 72827     40    2       1.0         1         2           1           2
# 72828     61    2       2.0         2         2           2           2
# 72829     66    1       2.0         2         2           2           2
# 72830     70    2       2.0         2         2           2           2
#
#        PHSTAT  MEDICAID  PRIVATE  WHONAM1  PLNWRKS1  DOINGLWP  WRKMYR  \
# 0           3         3        3      NaN       NaN       5.0     NaN
# 1           3         3        1      2.0       1.0       5.0     NaN
# 2           3         3        1      1.0       1.0       1.0    12.0
# 3           3         3        1      2.0       1.0       NaN     NaN
# 4           3         3        1      2.0       1.0       1.0    12.0
# ...       ...       ...      ...      ...       ...       ...     ...
# 72826       4         3        3      NaN       NaN       5.0     NaN
# 72827       5         3        1      1.0       1.0       2.0     1.0
# 72828       1         3        1      2.0       1.0       1.0    12.0
# 72829       1         3        1      1.0       1.0       1.0    12.0
# 72830       2         3        1      1.0       5.0       5.0     NaN
#
#        ERNYR_P  POWBEN  PCHLDSP  PINCOT
# 0          NaN       2        2       2
# 1          NaN       2        2       2
# 2          7.0       2        2       2
# 3          NaN       2        2       2
# 4         11.0       2        2       2
# ...        ...     ...      ...     ...
# 72826      NaN       2        2       1
# 72827      1.0       2        2       2
# 72828     10.0       2        2       2
# 72829     11.0       2        2       2
# 72830      NaN       2        2       2
#
# [72831 rows x 18 columns]

# %%
new2_df["PHSTAT"].value_counts(dropna=False)
# Out:
# 1    25109
# 2    22683
# 3    17432
# 4     5822
# 5     1711
# 7       50
# 9       24
# Name: PHSTAT, dtype: int64

# %%
indexNames = new2_df[new2_df['PHSTAT'] == 7].index

# %%
new2_df.drop(indexNames , inplace=True)

# %%
new2_df["PHSTAT"].value_counts(dropna=False)
# Out:
# 1    25109
# 2    22683
# 3    17432
# 4     5822
# 5     1711
# 9       24
# Name: PHSTAT, dtype: int64

# %%
indexNames2 = new2_df[new2_df['PHSTAT']==9].index

# %%
new2_df.drop(indexNames2, inplace=True)

# %%
new2_df["PHSTAT"].value_counts(dropna=False)
# Out:
# 1    25109
# 2    22683
# 3    17432
# 4     5822
# 5     1711
# Name: PHSTAT, dtype: int64

# %%
filterinfDataframe = new2_df[(new2_df['AGE_P'] > 25) & (new2_df['AGE_P'] < 39)]
filterinfDataframe
# Out:
#        AGE_P  SEX  PLAWKNOW  PDMED12M  PNMED12M  PDMED12M.1  PNMED12M.1  \
# 4         37    1       2.0         2         2           2           2
# 5         36    2       2.0         2         2           2           2
# 8         29    1       2.0         2         2           2           2
# 9         34    2       2.0         2         2           2           2
# 13        33    2       2.0         1         1           1           1
# ...      ...  ...       ...       ...       ...         ...         ...
# 72805     29    2       2.0         2         2           2           2
# 72810     34    1       2.0         2         2           2           2
# 72814     37    1       2.0         2         2           2           2
# 72818     31    1       2.0         2         2           2           2
# 72819     28    2       2.0         2         2           2           2
#
#        PHSTAT  MEDICAID  PRIVATE  WHONAM1  PLNWRKS1  DOINGLWP  WRKMYR  \
# 4           3         3        1      2.0       1.0       1.0    12.0
# 5           2         3        1      1.0       1.0       1.0    12.0
# 8           2         3        1      1.0       1.0       1.0    12.0
# 9           1         3        1      2.0       1.0       1.0    12.0
# 13          2         3        1      2.0       1.0       5.0     NaN
# ...       ...       ...      ...      ...       ...       ...     ...
# 72805       3         3        1      1.0       1.0       1.0    11.0
# 72810       2         3        1      1.0       1.0       1.0    12.0
# 72814       2         3        3      NaN       NaN       1.0     7.0
# 72818       2         3        1      1.0       1.0       1.0    12.0
# 72819       2         3        1      1.0       1.0       1.0    12.0
#
#        ERNYR_P  POWBEN  PCHLDSP  PINCOT
# 4         11.0       2        2       2
# 5         11.0       2        2       2
# 8          8.0       2        2       1
# 9          8.0       2        2       2
# 13         NaN       2        2       2
# ...        ...     ...      ...     ...
# 72805      6.0       2        2       2
# 72810      9.0       2        2       2
# 72814      5.0       2        2       2
# 72818      6.0       2        2       2
# 72819      4.0       2        2       2
#
# [11749 rows x 18 columns]

# %%
filterinfDataframe.to_csv("Output/filtered_health.csv",index=False)

# %%
milli_filtered = pd.read_csv('Output/filtered_health.csv')
print(milli_filtered.shape)
milli_filtered.head()
# Out:
# (11749, 18)
#    AGE_P  SEX  PLAWKNOW  PDMED12M  PNMED12M  PDMED12M.1  PNMED12M.1  PHSTAT  \
# 0     37    1       2.0         2         2           2           2       3
# 1     36    2       2.0         2         2           2           2       2
# 2     29    1       2.0         2         2           2           2       2
# 3     34    2       2.0         2         2           2           2       1
# 4     33    2       2.0         1         1           1           1       2
#
#    MEDICAID  PRIVATE  WHONAM1  PLNWRKS1  DOINGLWP  WRKMYR  ERNYR_P  POWBEN  \
# 0         3        1      2.0       1.0       1.0    12.0     11.0       2
# 1         3        1      1.0       1.0       1.0    12.0     11.0       2
# 2         3        1      1.0       1.0       1.0    12.0      8.0       2
# 3         3        1      2.0       1.0       1.0    12.0      8.0       2
# 4         3        1      2.0       1.0       5.0     NaN      NaN       2
#
#    PCHLDSP  PINCOT
# 0        2       2
# 1        2       2
# 2        2       1
# 3        2       2
# 4        2       2

# %%
milli_filtered.dtypes.value_counts()
# Out:
# int64      12
# float64     6
# dtype: int64

# %%
milli_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11749 entries, 0 to 11748
# Data columns (total 18 columns):
# AGE_P         11749 non-null int64
# SEX           11749 non-null int64
# PLAWKNOW      11749 non-null float64
# PDMED12M      11749 non-null int64
# PNMED12M      11749 non-null int64
# PDMED12M.1    11749 non-null int64
# PNMED12M.1    11749 non-null int64
# PHSTAT        11749 non-null int64
# MEDICAID      11749 non-null int64
# PRIVATE       11749 non-null int64
# WHONAM1       7623 non-null float64
# PLNWRKS1      7623 non-null float64
# DOINGLWP      11749 non-null float64
# WRKMYR        9992 non-null float64
# ERNYR_P       9992 non-null float64
# POWBEN        11749 non-null int64
# PCHLDSP       11749 non-null int64
# PINCOT        11749 non-null int64
# dtypes: float64(6), int64(12)
# memory usage: 1.6 MB

# %%
null_counts = milli_filtered.isnull().sum()
print("Number of null values in each column:\n{}".format(null_counts))
# Out:
# Number of null values in each column:
# AGE_P            0
# SEX              0
# PLAWKNOW         0
# PDMED12M         0
# PNMED12M         0
# PDMED12M.1       0
# PNMED12M.1       0
# PHSTAT           0
# MEDICAID         0
# PRIVATE          0
# WHONAM1       4126
# PLNWRKS1      4126
# DOINGLWP         0
# WRKMYR        1757
# ERNYR_P       1757
# POWBEN           0
# PCHLDSP          0
# PINCOT           0
# dtype: int64

# %%
milli_filtered=milli_filtered.dropna()

# %%
X=milli_filtered.loc[:,["AGE_P","WRKMYR","ERNYR_P"]]
y=milli_filtered["PHSTAT"].values.reshape(-1, 1)

# %%
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (6988, 2) (6988, 1)

# %%
from sklearn.model_selection import train_test_split

### BEGIN SOLUTION

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (5241, 2)
# (5241, 1)

# %%
# Create and score a decision tree classifier
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %%
importances = clf.feature_importances_
importances
# Out:
# array([0.60660028, 0.39339972])

# %%
prediction = clf.predict(X_test)

# %%
clf.score(X_test, y_test)
# Out:
# 0.39152833428734973
